# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

# %% [markdown]
# ## dataset

# %% [markdown]
# #### Os dados foram consultados desse link ~>

# %%
path = 'datasets/'
startName = 'dataset_of_'
filenames = {'janeiro', 'fevereiro', 'marco', 'abril', 'maio', 'junho', 'julho', 'agosto', 'setembro'}
extension = '.xlsx'

# %%
#Função para percorrer os arquivos de dados e popular o dataframe.
def populaDataFrame():
    dfList = list()

    for file in filenames:
        df= pd.DataFrame(pd.read_excel(path+startName+file+extension))
        dfList.append(df)

    df = pd.concat(dfList)
    return df

# %%
df = populaDataFrame()
df.reset_index()
# Out:
#      index  ANO_BO  NUM_BO NUMERO_BOLETIM         BO_INICIADO  \
# 0        0    2018     769       769/2018 2018-07-03 09:28:27
# 1        1    2018     880       880/2018 2018-07-03 22:03:23
# 2        2    2018     881       881/2018 2018-07-04 03:25:31
# 3        3    2018     112       112/2018 2018-07-05 14:25:09
# 4        4    2018     112       112/2018 2018-07-05 14:25:09
# 5        5    2018    1605      1605/2018 2018-07-06 12:46:47
# 6        6    2018    1605      1605/2018 2018-07-06 12:46:47
# 7        7    2018    1605      1605/2018 2018-07-06 12:46:47
# 8        8    2018     103       103/2018 2018-07-06 18:49:03
# 9        9    2018    1745      1745/2018 2018-07-07 04:57:37
# 10      10    2018    2602      2602/2018 2018-07-07 09:47:56
# 11      11    2018    2699      2699/2018 2018-07-08 16:12:47
# 12      12    2018    2705      2705/2018 2018-07-08 17:31:39
# 13      13    2018    2713      2713/2018 2018-07-08 23:03:55
# ...

# %%
filename = 'datasets/DadosBO2018SetembroHOMICIDIO.xlsx'
df1 = pd.read_excel(filename)

# %%
df.groupby('CIDADE').size().sort_values().tail(10).plot(kind='barh', figsize=(14,14))

# %%
df.groupby('SEXO').size().sort_values().tail(10).plot(kind='pie',title = 'Sexo', figsize=(6,6), x = 'abacate')

# %%
df.groupby('NATUREZAVINCULADA').size().sort_values().tail(10).plot(kind='barh', figsize=(6,6))
