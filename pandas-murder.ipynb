# %% [markdown]
# ## Análise sobre homicídio doloso em São José dos Campos e região (de janeiro/2018 até setembro/2018)

# %% [markdown]
#  **Faculdade**: FATEC Jessen Vidal de São José dos Campos
#
#  **Aluno**: Jefferson de Moura
#
#  **Aluno**: Vitor Hugo
#
#  **Aluno**: Yasmin Araújo
#
#  **Professor**: Me. Fernando Masanori Ashikaga

# %% [markdown]
# ### dataset: http://www.ssp.sp.gov.br/transparenciassp/

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
plt.style.use('fivethirtyeight')
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

# %%
path = 'datasets/'
startName = 'homicidios_de_'
filenames = {'janeiro', 'fevereiro', 'marco', 'abril', 'maio', 'junho', 'julho', 'agosto', 'setembro'}
extension = '.xlsx'

# %%
def populaDataFrame():
    dfList = list()

    for file in filenames:
        df= pd.DataFrame(pd.read_excel(path+startName+file+extension))
        dfList.append(df)

    df = pd.concat(dfList)
    return df

# %%
df = populaDataFrame()

# %% [markdown]
# ## 1. Número de homicídios por cidade

# %%
df.groupby('CIDADE').size().sort_values().tail(10).plot(kind='barh', figsize=(10,6))

# %% [markdown]
# ## 2. Comparação de vítimas por gênero

# %%
df.groupby('SEXO').size().sort_values().tail(10).plot(kind='pie',title = 'Gênero', figsize=(10,6))

# %% [markdown]
# ## 3. Periodo da ocorrência mais comum em São José dos Campos

# %%
df.query('CIDADE == "S.JOSE DOS CAMPOS"').groupby('PERIDOOCORRENCIA').size().sort_values().tail().plot(kind='barh', figsize=(10,6));

# %% [markdown]
# ## 4. Periodo da ocorrência mais comum em Taubaté

# %%
df.query('CIDADE == "TAUBATE"').groupby('PERIDOOCORRENCIA').size().sort_values().tail().plot(kind='barh', figsize=(10,6));

# %% [markdown]
# ## 5. Localização mais comuns dos homicídios

# %%
df.groupby('DESCRICAOLOCAL').size().sort_values().tail(8).plot(kind='barh', figsize=(10,6))
